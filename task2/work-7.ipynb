# %% [markdown]
# ## I. Importing essential libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import os
print(os.listdir())

import warnings
warnings.filterwarnings('ignore')
# Out:
# ['.ipynb_checkpoints', 'heart_cleveland_upload.csv', 'work 7 final doc.docx', 'work-7.ipynb', 'work7.docx']

# %% [markdown]
# ## II. Importing and understanding our dataset

# %%
dataset = pd.read_csv("heart_cleveland_upload.csv")

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (297, 14)

# %%
dataset.tail(10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 287   42    0   3       102   265    0        2      122      0      0.6
# 288   42    1   3       136   315    0        0      125      1      1.8
# 289   42    1   3       140   226    0        0      178      0      0.0
# 290   41    1   3       110   172    0        2      158      0      0.0
# 291   40    1   3       110   167    0        2      114      1      2.0
# 292   40    1   3       152   223    0        0      181      0      0.0
# 293   39    1   3       118   219    0        0      140      0      1.2
# 294   35    1   3       120   198    0        0      130      1      1.6
# 295   35    0   3       138   183    0        0      182      0      1.4
# 296   35    1   3       126   282    0        2      156      1      0.0
#
#      slope  ca  thal  condition
# 287      1   0     0          0
# 288      1   0     1          1
# 289      0   0     0          0
# 290      0   0     2          1
# ...

# %%
dataset.sample(15)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 234   56    0   3       200   288    1        2      133      1      4.0
# 174   64    1   3       120   246    0        2       96      1      2.2
# 107   54    1   2       125   273    0        2      152      0      0.5
# 54    46    1   1       101   197    1        0      156      0      0.0
# 115   53    1   2       130   246    1        2      173      0      0.0
# 73    71    0   2       110   265    1        2      130      0      0.0
# 146   42    1   2       130   180    0        0      150      0      0.0
# 32    58    0   1       136   319    1        2      152      0      0.0
# 66    41    1   1       110   235    0        0      153      0      0.0
# 28    62    1   1       120   281    0        2      103      0      1.4
# 181   63    0   3       108   269    0        0      169      1      1.8
# 23    74    0   1       120   269    0        2      121      1      0.2
# ...

# %%
dataset.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean    54.542088    0.676768    2.158249  131.693603  247.350168    0.144781
# std      9.049736    0.468500    0.964859   17.762806   51.997583    0.352474
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    2.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    3.000000  140.000000  276.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  297.000000  297.000000  297.000000  297.000000  297.000000  297.000000
# mean     0.996633  149.599327    0.326599    1.055556    0.602694    0.676768
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        297 non-null    int64
#  1   sex        297 non-null    int64
#  2   cp         297 non-null    int64
#  3   trestbps   297 non-null    int64
#  4   chol       297 non-null    int64
#  5   fbs        297 non-null    int64
#  6   restecg    297 non-null    int64
#  7   thalach    297 non-null    int64
#  8   exang      297 non-null    int64
#  9   oldpeak    297 non-null    float64
#  10  slope      297 non-null    int64
#  11  ca         297 non-null    int64
#  12  thal       297 non-null    int64
#  13  condition  297 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 32.6 KB

# %% [markdown]
# #### Let's understand our columns better:

# %%
info = ["age","1: male, 0: female","chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic","resting blood pressure"," serum cholestoral in mg/dl","fasting blood sugar > 120 mg/dl","resting electrocardiographic results (values 0,1,2)"," maximum heart rate achieved","exercise induced angina","oldpeak = ST depression induced by exercise relative to rest","the slope of the peak exercise ST segment","number of major vessels (0-3) colored by flourosopy","thal: 3 = normal; 6 = fixed defect; 7 = reversable defect"]



for i in range(len(info)):
    print(dataset.columns[i]+":\t\t\t"+info[i])
# Out:
# age:			age
# sex:			1: male, 0: female
# cp:			chest pain type, 1: typical angina, 2: atypical angina, 3: non-anginal pain, 4: asymptomatic
# trestbps:			resting blood pressure
# chol:			 serum cholestoral in mg/dl
# fbs:			fasting blood sugar > 120 mg/dl
# restecg:			resting electrocardiographic results (values 0,1,2)
# thalach:			 maximum heart rate achieved
# exang:			exercise induced angina
# oldpeak:			oldpeak = ST depression induced by exercise relative to rest
# slope:			the slope of the peak exercise ST segment
# ca:			number of major vessels (0-3) colored by flourosopy
# thal:			thal: 3 = normal; 6 = fixed defect; 7 = reversable defect

# %%
dataset["condition"].describe()
# Out:
# count    297.000000
# mean       0.461279
# std        0.499340
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: condition, dtype: float64

# %%
dataset["condition"].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# ### Checking correlation between columns

# %%
print(dataset.corr()["condition"].abs().sort_values(ascending=False))
# Out:
# condition    1.000000
# thal         0.520516
# ca           0.463189
# oldpeak      0.424052
# thalach      0.423817
# exang        0.421355
# cp           0.408945
# slope        0.333049
# sex          0.278467
# age          0.227075
# restecg      0.166343
# trestbps     0.153490
# chol         0.080285
# fbs          0.003167
# Name: condition, dtype: float64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
y = dataset["condition"]

sns.countplot(y)


condition_temp = dataset.condition.value_counts()

print(condition_temp)
# Out:
# 0    160
# 1    137
# Name: condition, dtype: int64

# %%
print("Percentage of patience without heart problems: "+str(round(condition_temp[0]*100/303,2)))
print("Percentage of patience with heart problems: "+str(round(condition_temp[1]*100/303,2)))

#Alternatively,
# print("Percentage of patience with heart problems: "+str(y.where(y==1).count()*100/303))
# print("Percentage of patience with heart problems: "+str(y.where(y==0).count()*100/303))

# #Or,
# countNoDisease = len(df[df.target == 0])
# countHaveDisease = len(df[df.target == 1])
# Out:
# Percentage of patience without heart problems: 52.81
# Percentage of patience with heart problems: 45.21

# %%
dataset["sex"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.barplot(dataset["sex"],y)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='condition'>

# %%
dataset["cp"].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
sns.barplot(dataset["cp"],y)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='condition'>

# %%
dataset["fbs"].describe()
# Out:
# count    297.000000
# mean       0.144781
# std        0.352474
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# Name: fbs, dtype: float64

# %%
dataset["fbs"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
sns.barplot(dataset["fbs"],y)
# Out:
# <AxesSubplot:xlabel='fbs', ylabel='condition'>

# %%
dataset["restecg"].unique()
# Out:
# array([2, 0, 1], dtype=int64)

# %%
sns.barplot(dataset["restecg"],y)
# Out:
# <AxesSubplot:xlabel='restecg', ylabel='condition'>

# %%
dataset["exang"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.barplot(dataset["exang"],y)
# Out:
# <AxesSubplot:xlabel='exang', ylabel='condition'>

# %%
dataset["slope"].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
sns.barplot(dataset["slope"],y)
# Out:
# <AxesSubplot:xlabel='slope', ylabel='condition'>

# %%
#number of major vessels (0-3) colored by flourosopy

# %%
dataset["ca"].unique()
# Out:
# array([1, 2, 0, 3], dtype=int64)

# %%
sns.countplot(dataset["ca"])
# Out:
# <AxesSubplot:xlabel='ca', ylabel='count'>

# %%
sns.barplot(dataset["ca"],y)
# Out:
# <AxesSubplot:xlabel='ca', ylabel='condition'>

# %%
### Analysing the 'thal' feature

# %%
dataset["thal"].unique()
# Out:
# array([0, 2, 1], dtype=int64)

# %%
sns.barplot(dataset["thal"],y)
# Out:
# <AxesSubplot:xlabel='thal', ylabel='condition'>

# %%
sns.distplot(dataset["thal"])
# Out:
# <AxesSubplot:xlabel='thal', ylabel='Density'>

# %%
#heart.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# add bins ^^^

dataset.hist(figsize=(16, 20), xlabelsize=8, ylabelsize=8)
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'cp'}>,
#         <AxesSubplot:title={'center':'trestbps'}>],
#        [<AxesSubplot:title={'center':'chol'}>,
#         <AxesSubplot:title={'center':'fbs'}>,
#         <AxesSubplot:title={'center':'restecg'}>,
#         <AxesSubplot:title={'center':'thalach'}>],
#        [<AxesSubplot:title={'center':'exang'}>,
#         <AxesSubplot:title={'center':'oldpeak'}>,
#         <AxesSubplot:title={'center':'slope'}>,
#         <AxesSubplot:title={'center':'ca'}>],
#        [<AxesSubplot:title={'center':'thal'}>,
#         <AxesSubplot:title={'center':'condition'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.pairplot(dataset, hue='condition')

# %%
dataset.corr()
# Out:
#                 age       sex        cp  trestbps      chol       fbs  \
# age        1.000000 -0.092399  0.110471  0.290476  0.202644  0.132062
# sex       -0.092399  1.000000  0.008908 -0.066340 -0.198089  0.038850
# cp         0.110471  0.008908  1.000000 -0.036980  0.072088 -0.057663
# trestbps   0.290476 -0.066340 -0.036980  1.000000  0.131536  0.180860
# chol       0.202644 -0.198089  0.072088  0.131536  1.000000  0.012708
# fbs        0.132062  0.038850 -0.057663  0.180860  0.012708  1.000000
# restecg    0.149917  0.033897  0.063905  0.149242  0.165046  0.068831
# thalach   -0.394563 -0.060496 -0.339308 -0.049108 -0.000075 -0.007842
# exang      0.096489  0.143581  0.377525  0.066691  0.059339 -0.000893
# oldpeak    0.197123  0.106567  0.203244  0.191243  0.038596  0.008311
# slope      0.159405  0.033345  0.151079  0.121172 -0.009215  0.047819
# ca         0.362210  0.091925  0.235644  0.097954  0.115945  0.152086
# ...

# %%
f, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(dataset.corr(),annot=True,cmap='coolwarm',linewidths=.5)
# Out:
# <AxesSubplot:>

# %%
dataset['sex'].value_counts()
# Out:
# 1    201
# 0     96
# Name: sex, dtype: int64

# %%
dataset.groupby(['sex', 'condition'])['sex'].count()
# Out:
# sex  condition
# 0    0             71
#      1             25
# 1    0             89
#      1            112
# Name: sex, dtype: int64

# %%
sns.countplot(data=dataset, x='sex', hue='condition')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
dataset['sex'].corr(dataset['condition'])
# Out:
# 0.278466696653796

# %%
sns.countplot(data=dataset, x='cp', hue='condition')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
dataset['cp'].corr(dataset['condition'])
# Out:
# 0.40894468667523853

# %%
sns.countplot(data=dataset, x='slope', hue='condition')
# Out:
# <AxesSubplot:xlabel='slope', ylabel='count'>

# %%
dataset['slope'].corr(dataset['condition'])
# Out:
# 0.33304910873955573

# %%
sns.distplot(dataset['thalach'])
# Out:
# <AxesSubplot:xlabel='thalach', ylabel='Density'>

# %%
f, ax = plt.subplots(figsize=(15, 5))
sns.countplot(data=dataset, x=pd.cut(dataset['thalach'], 10), hue='condition')
# Out:
# <AxesSubplot:xlabel='thalach', ylabel='count'>

# %%
dataset['thalach'].corr(dataset['condition'])
# Out:
# -0.42381706418337134

# %%
sns.countplot(data=dataset, x='thal', hue='condition')
# Out:
# <AxesSubplot:xlabel='thal', ylabel='count'>

# %%
dataset['thal'].corr(dataset['condition'])
# Out:
# 0.5205164641924137

# %%
dataset['ca'].corr(dataset['condition'])
# Out:
# 0.4631886250630225

# %%
#bin oldpeak with pd.cut

sns.countplot(data=dataset, x=pd.cut(dataset['oldpeak'], 6, labels=[0,1,2,3,4,5]), hue='condition')
# Out:
# <AxesSubplot:xlabel='oldpeak', ylabel='count'>

# %%
dataset['oldpeak'].corr(dataset['condition'])
# Out:
# 0.4240520567159996

# %%
sns.distplot(dataset['ca'])
sns.distplot(dataset['oldpeak'])
# Out:
# <AxesSubplot:xlabel='oldpeak', ylabel='Density'>

# %%
dataset['age'].describe()
# Out:
# count    297.000000
# mean      54.542088
# std        9.049736
# min       29.000000
# 25%       48.000000
# 50%       56.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
dataset['age'].mean()
# Out:
# 54.54208754208754

# %%
sns.distplot(dataset['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.distplot(dataset['trestbps'])
# Out:
# <AxesSubplot:xlabel='trestbps', ylabel='Density'>

# %%
sns.pairplot(dataset , vars = ['age', 'chol', 'thal', 'oldpeak'], hue='condition')

# %% [markdown]
# ## IV. Train Test split

# %%
from sklearn.model_selection import train_test_split

predictors = dataset.drop("condition",axis=1)
target = dataset["condition"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (237, 13)

# %%
X_test.shape
# Out:
# (60, 13)

# %%
Y_train.shape
# Out:
# (237,)

# %%
Y_test.shape
# Out:
# (60,)

# %% [markdown]
# ## V. Model Fitting

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

max_accuracy = 0


for x in range(2000):
    rf = RandomForestClassifier(random_state=x)
    rf.fit(X_train,Y_train)
    Y_pred_rf = rf.predict(X_test)
    current_accuracy = round(accuracy_score(Y_pred_rf,Y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x = x
        
#print(max_accuracy)
#print(best_x)

rf = RandomForestClassifier(random_state=best_x)
rf.fit(X_train,Y_train)
Y_pred_rf = rf.predict(X_test)

# %%
Y_pred_rf.shape
# Out:
# (60,)

# %%
score_rf = round(accuracy_score(Y_pred_rf,Y_test)*100,2)

print("The accuracy score achieved using Random Forest is: "+str(score_rf)+" %")
# Out:
# The accuracy score achieved using Random Forest is: 81.67 %

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42)
xgb_model.fit(X_train, Y_train)

Y_pred_xgb = xgb_model.predict(X_test)
# Out:
# [12:02:47] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
Y_pred_xgb.shape
# Out:
# (60,)

# %%
score_xgb = round(accuracy_score(Y_pred_xgb,Y_test)*100,2)

print("The accuracy score achieved using XGBoost is: "+str(score_xgb)+" %")
# Out:
# The accuracy score achieved using XGBoost is: 71.67 %

# %% [markdown]
# ## VI. Output final score

# %%
scores = [score_rf,score_xgb]
algorithms = ["Random Forest","XGBoost"]    

for i in range(len(algorithms)):
    print("The accuracy score achieved using "+algorithms[i]+" is: "+str(scores[i])+" %")
# Out:
# The accuracy score achieved using Random Forest is: 81.67 %
# The accuracy score achieved using XGBoost is: 71.67 %

# %%
sns.set(rc={'figure.figsize':(15,8)})
plt.xlabel("Algorithms")
plt.ylabel("Accuracy score")

sns.barplot(algorithms,scores)
# Out:
# <AxesSubplot:xlabel='Algorithms', ylabel='Accuracy score'>
